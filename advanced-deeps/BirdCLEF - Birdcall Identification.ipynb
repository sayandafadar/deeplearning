# %%
import tensorflow as tf

# %%
_ = tf.keras.utils.get_file('train_short_audio.zip',
                        'https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/25954/2091745/compressed/train_short_audio.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1682924031&Signature=pFADmV96opDPJ2NxUY1zw0wxuKQ29dWkO%2BEi4zdDBOT4t%2Fs6UQZuO4SKFQs26ZLLjre3YE%2FGk7jrgVcHdEav8Xkifq2QhjVOr%2Fb214LTJJlbOT6Mc5PoNEKlUnz7aj%2FRcYuXddQUi8viSAcDg4%2BYizKMhoF%2BO9AD%2BLakArbw%2FRQoEsg1uHfCC1BgQVuZCy5XdISPmTacESQUROy0mCaeGl798LUNlvMsmdnfX4tv7BO7htu1G4mk8soICRtfCmL2nY09EE5TZuY8Jqt%2Bn%2B86dFw0G6UvHOXeqrk%2FnPlvW9P4XI3wsxdUloTUpT8yx2i5iPVKOjGWy%2BOgRsycyuRJrQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_short_audio.zip',
                        cache_dir='./',
                        cache_subdir='datasets',
                        extract=True)
# Out:
# ...
# 41918575709/41918575709 [==============================] - 280s 0us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/utils/data_utils.py in _extract_archive(file_path, path, archive_format)
#     175                         # Zip archive.
# --> 176                         archive.extractall(path)
#     177                     else:
#
# /usr/lib/python3.10/zipfile.py in extractall(self, path, members, pwd)
#    1646         for zipinfo in members:
# -> 1647             self._extract_member(zipinfo, path, pwd)
#    1648
#
# /usr/lib/python3.10/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1701              open(targetpath, "wb") as target:
# -> 1702             shutil.copyfileobj(source, target)
#    1703
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     197             break
# ...
