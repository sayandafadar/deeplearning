# %% [markdown]
# # Introduction to Convolutional Neural Networks and Computer Vision with Tensorflow
#
# Computer vision is the practice is writing alogrithms which can discover patterns in visual data. Such as the camera of a self-driving car recognizing the car in front.

# %% [markdown]
# ## Get the data

# %%
import zipfile

# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip 

# Unzip the downloaded file
zip_ref = zipfile.ZipFile("pizza_steak.zip")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2023-02-03 13:23:49--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.202.128, 74.125.69.128, 64.233.181.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109540975 (104M) [application/zip]
# Saving to: ‘pizza_steak.zip’
#
# pizza_steak.zip     100%[===================>] 104.47M   260MB/s    in 0.4s
#
# 2023-02-03 13:23:50 (260 MB/s) - ‘pizza_steak.zip’ saved [109540975/109540975]

# %% [markdown]
# ## Inspect the data (become one with it)
#
# A very crucial step at the beginning of any machine learning project is becoming one with the data.
#
# And for a computer vision project... this usually means visualizing many samples of your data.

# %%
# !ls pizza_steak
# Out:
# test  train

# %%
# !ls pizza_steak/train/
# Out:
# pizza  steak

# %%
# !ls pizza_steak/train/steak
# Out:
# 1000205.jpg  1647351.jpg  2238681.jpg  2824680.jpg  3375959.jpg  417368.jpg
# 100135.jpg   1650002.jpg  2238802.jpg  2825100.jpg  3381560.jpg  4176.jpg
# 101312.jpg   165639.jpg   2254705.jpg  2826987.jpg  3382936.jpg  42125.jpg
# 1021458.jpg  1658186.jpg  225990.jpg   2832499.jpg  3386119.jpg  421476.jpg
# 1032846.jpg  1658443.jpg  2260231.jpg  2832960.jpg  3388717.jpg  421561.jpg
# 10380.jpg    165964.jpg   2268692.jpg  285045.jpg   3389138.jpg  438871.jpg
# 1049459.jpg  167069.jpg   2271133.jpg  285147.jpg   3393547.jpg  43924.jpg
# 1053665.jpg  1675632.jpg  227576.jpg   2855315.jpg  3393688.jpg  440188.jpg
# 1068516.jpg  1678108.jpg  2283057.jpg  2856066.jpg  3396589.jpg  442757.jpg
# 1068975.jpg  168006.jpg   2286639.jpg  2859933.jpg  339891.jpg	 443210.jpg
# 1081258.jpg  1682496.jpg  2287136.jpg  286219.jpg   3417789.jpg  444064.jpg
# 1090122.jpg  1684438.jpg  2291292.jpg  2862562.jpg  3425047.jpg  444709.jpg
# 1093966.jpg  168775.jpg   229323.jpg   2865730.jpg  3434983.jpg  447557.jpg
# 1098844.jpg  1697339.jpg  2300534.jpg  2878151.jpg  3435358.jpg  461187.jpg
# 1100074.jpg  1710569.jpg  2300845.jpg  2880035.jpg  3438319.jpg  461689.jpg
# 1105280.jpg  1714605.jpg  231296.jpg   2881783.jpg  3444407.jpg  465494.jpg
# 1117936.jpg  1724387.jpg  2315295.jpg  2884233.jpg  345734.jpg	 468384.jpg
# 1126126.jpg  1724717.jpg  2323132.jpg  2890573.jpg  3460673.jpg  477486.jpg
# 114601.jpg   172936.jpg   2324994.jpg  2893832.jpg  3465327.jpg  482022.jpg
# 1147047.jpg  1736543.jpg  2327701.jpg  2893892.jpg  3466159.jpg  482465.jpg
# 1147883.jpg  1736968.jpg  2331076.jpg  2907177.jpg  3469024.jpg  483788.jpg
# 1155665.jpg  1746626.jpg  233964.jpg   290850.jpg   3470083.jpg  493029.jpg
# 1163977.jpg  1752330.jpg  2344227.jpg  2909031.jpg  3476564.jpg  503589.jpg
# 1190233.jpg  1761285.jpg  234626.jpg   2910418.jpg  3478318.jpg  510757.jpg
# 1208405.jpg  176508.jpg   234704.jpg   2912290.jpg  3488748.jpg  513129.jpg
# 1209120.jpg  1772039.jpg  2357281.jpg  2916448.jpg  3492328.jpg  513842.jpg
# 1212161.jpg  1777107.jpg  2361812.jpg  2916967.jpg  3518960.jpg  523535.jpg
# 1213988.jpg  1787505.jpg  2365287.jpg  2927833.jpg  3522209.jpg  525041.jpg
# 1219039.jpg  179293.jpg   2374582.jpg  2928643.jpg  3524429.jpg  534560.jpg
# 1225762.jpg  1816235.jpg  239025.jpg   2929179.jpg  3528458.jpg  534633.jpg
# 1230968.jpg  1822407.jpg  2390628.jpg  2936477.jpg  3531805.jpg  536535.jpg
# 1236155.jpg  1823263.jpg  2392910.jpg  2938012.jpg  3536023.jpg  541410.jpg
# 1241193.jpg  1826066.jpg  2394465.jpg  2938151.jpg  3538682.jpg  543691.jpg
# 1248337.jpg  1828502.jpg  2395127.jpg  2939678.jpg  3540750.jpg  560503.jpg
# 1257104.jpg  1828969.jpg  2396291.jpg  2940544.jpg  354329.jpg	 561972.jpg
# 126345.jpg   1829045.jpg  2400975.jpg  2940621.jpg  3547166.jpg  56240.jpg
# 1264050.jpg  1829088.jpg  2403776.jpg  2949079.jpg  3553911.jpg  56409.jpg
# 1264154.jpg  1836332.jpg  2403907.jpg  295491.jpg   3556871.jpg  564530.jpg
# 1264858.jpg  1839025.jpg  240435.jpg   296268.jpg   355715.jpg	 568972.jpg
# 127029.jpg   1839481.jpg  2404695.jpg  2964732.jpg  356234.jpg	 576725.jpg
# 1289900.jpg  183995.jpg   2404884.jpg  2965021.jpg  3571963.jpg  588739.jpg
# 1290362.jpg  184110.jpg   2407770.jpg  2966859.jpg  3576078.jpg  590142.jpg
# 1295457.jpg  184226.jpg   2412263.jpg  2977966.jpg  3577618.jpg  60633.jpg
# 1312841.jpg  1846706.jpg  2425062.jpg  2979061.jpg  3577732.jpg  60655.jpg
# 1313316.jpg  1849364.jpg  2425389.jpg  2983260.jpg  3578934.jpg  606820.jpg
# 1324791.jpg  1849463.jpg  2435316.jpg  2984311.jpg  358042.jpg	 612551.jpg
# 1327567.jpg  1849542.jpg  2437268.jpg  2988960.jpg  358045.jpg	 614975.jpg
# 1327667.jpg  1853564.jpg  2437843.jpg  2989882.jpg  3591821.jpg  616809.jpg
# 1333055.jpg  1869467.jpg  2440131.jpg  2995169.jpg  359330.jpg	 628628.jpg
# 1334054.jpg  1870942.jpg  2443168.jpg  2996324.jpg  3601483.jpg  632427.jpg
# 1335556.jpg  187303.jpg   2446660.jpg  3000131.jpg  3606642.jpg  636594.jpg
# 1337814.jpg  187521.jpg   2455944.jpg  3002350.jpg  3609394.jpg  637374.jpg
# 1340977.jpg  1888450.jpg  2458401.jpg  3007772.jpg  361067.jpg	 640539.jpg
# 1343209.jpg  1889336.jpg  2487306.jpg  3008192.jpg  3613455.jpg  644777.jpg
# 134369.jpg   1907039.jpg  248841.jpg   3009617.jpg  3621464.jpg  644867.jpg
# 1344105.jpg  1925230.jpg  2489716.jpg  3011642.jpg  3621562.jpg  658189.jpg
# 134598.jpg   1927984.jpg  2490489.jpg  3020591.jpg  3621565.jpg  660900.jpg
# 1346387.jpg  1930577.jpg  2495884.jpg  3030578.jpg  3623556.jpg  663014.jpg
# 1348047.jpg  1937872.jpg  2495903.jpg  3047807.jpg  3640915.jpg  664545.jpg
# 1351372.jpg  1941807.jpg  2499364.jpg  3059843.jpg  3643951.jpg  667075.jpg
# 1362989.jpg  1942333.jpg  2500292.jpg  3074367.jpg  3653129.jpg  669180.jpg
# 1367035.jpg  1945132.jpg  2509017.jpg  3082120.jpg  3656752.jpg  669960.jpg
# 1371177.jpg  1961025.jpg  250978.jpg   3094354.jpg  3663518.jpg  6709.jpg
# 1375640.jpg  1966300.jpg  2514432.jpg  3095301.jpg  3663800.jpg  674001.jpg
# 1382427.jpg  1966967.jpg  2526838.jpg  3099645.jpg  3664376.jpg  676189.jpg
# 1392718.jpg  1969596.jpg  252858.jpg   3100476.jpg  3670607.jpg  681609.jpg
# 1395906.jpg  1971757.jpg  2532239.jpg  3110387.jpg  3671021.jpg  6926.jpg
# 1400760.jpg  1976160.jpg  2534567.jpg  3113772.jpg  3671877.jpg  703556.jpg
# 1403005.jpg  1984271.jpg  2535431.jpg  3116018.jpg  368073.jpg	 703909.jpg
# 1404770.jpg  1987213.jpg  2535456.jpg  3128952.jpg  368162.jpg	 704316.jpg
# 140832.jpg   1987639.jpg  2538000.jpg  3130412.jpg  368170.jpg	 714298.jpg
# 141056.jpg   1995118.jpg  2543081.jpg  3136.jpg     3693649.jpg  720060.jpg
# 141135.jpg   1995252.jpg  2544643.jpg  313851.jpg   3700079.jpg  726083.jpg
# 1413972.jpg  199754.jpg   2547797.jpg  3140083.jpg  3704103.jpg  728020.jpg
# 1421393.jpg  2002400.jpg  2548974.jpg  3140147.jpg  3707493.jpg  732986.jpg
# 1428947.jpg  2011264.jpg  2549316.jpg  3142045.jpg  3716881.jpg  734445.jpg
# 1433912.jpg  2012996.jpg  2561199.jpg  3142618.jpg  3724677.jpg  735441.jpg
# 143490.jpg   2013535.jpg  2563233.jpg  3142674.jpg  3727036.jpg  740090.jpg
# 1445352.jpg  2017387.jpg  256592.jpg   3143192.jpg  3727491.jpg  745189.jpg
# 1446401.jpg  2018173.jpg  2568848.jpg  314359.jpg   3736065.jpg  752203.jpg
# 1453991.jpg  2020613.jpg  2573392.jpg  3157832.jpg  37384.jpg	 75537.jpg
# 1456841.jpg  2032669.jpg  2592401.jpg  3159818.jpg  3743286.jpg  756655.jpg
# 146833.jpg   203450.jpg   2599817.jpg  3162376.jpg  3745515.jpg  762210.jpg
# 1476404.jpg  2034628.jpg  2603058.jpg  3168620.jpg  3750472.jpg  763690.jpg
# 1485083.jpg  2036920.jpg  2606444.jpg  3171085.jpg  3752362.jpg  767442.jpg
# 1487113.jpg  2038418.jpg  2614189.jpg  317206.jpg   3766099.jpg  786409.jpg
# 148916.jpg   2042975.jpg  2614649.jpg  3173444.jpg  3770370.jpg  80215.jpg
# 149087.jpg   2045647.jpg  2615718.jpg  3180182.jpg  377190.jpg	 802348.jpg
# 1493169.jpg  2050584.jpg  2619625.jpg  31881.jpg    3777020.jpg  804684.jpg
# 149682.jpg   2052542.jpg  2622140.jpg  3191589.jpg  3777482.jpg  812163.jpg
# 1508094.jpg  2056627.jpg  262321.jpg   3204977.jpg  3781152.jpg  813486.jpg
# 1512226.jpg  2062248.jpg  2625330.jpg  320658.jpg   3787809.jpg  819027.jpg
# 1512347.jpg  2081995.jpg  2628106.jpg  3209173.jpg  3788729.jpg  822550.jpg
# 1524526.jpg  2087958.jpg  2629750.jpg  3223400.jpg  3790962.jpg  823766.jpg
# 1530833.jpg  2088030.jpg  2643906.jpg  3223601.jpg  3792514.jpg  827764.jpg
# 1539499.jpg  2088195.jpg  2644457.jpg  3241894.jpg  379737.jpg	 830007.jpg
# 1541672.jpg  2090493.jpg  2648423.jpg  3245533.jpg  3807440.jpg  838344.jpg
# 1548239.jpg  2090504.jpg  2651300.jpg  3245622.jpg  381162.jpg	 853327.jpg
# 1550997.jpg  2125877.jpg  2653594.jpg  3247009.jpg  3812039.jpg  854150.jpg
# 1552530.jpg  2129685.jpg  2661577.jpg  3253588.jpg  3829392.jpg  864997.jpg
# 15580.jpg    2133717.jpg  2668916.jpg  3260624.jpg  3830872.jpg  885571.jpg
# 1559052.jpg  2136662.jpg  268444.jpg   326587.jpg   38442.jpg	 907107.jpg
# 1563266.jpg  213765.jpg   2691461.jpg  32693.jpg    3855584.jpg  908261.jpg
# 1567554.jpg  2138335.jpg  2706403.jpg  3271253.jpg  3857508.jpg  910672.jpg
# 1575322.jpg  2140776.jpg  270687.jpg   3274423.jpg  386335.jpg	 911803.jpg
# 1588879.jpg  214320.jpg   2707522.jpg  3280453.jpg  3867460.jpg  91432.jpg
# 1594719.jpg  2146963.jpg  2711806.jpg  3298495.jpg  3868959.jpg  914570.jpg
# 1595869.jpg  215222.jpg   2716993.jpg  330182.jpg   3869679.jpg  922752.jpg
# 1598345.jpg  2154126.jpg  2724554.jpg  3306627.jpg  388776.jpg	 923772.jpg
# 1598885.jpg  2154779.jpg  2738227.jpg  3315727.jpg  3890465.jpg  926414.jpg
# 1600179.jpg  2159975.jpg  2748917.jpg  331860.jpg   3894222.jpg  931356.jpg
# 1600794.jpg  2163079.jpg  2760475.jpg  332232.jpg   3895825.jpg  937133.jpg
# 160552.jpg   217250.jpg   2761427.jpg  3322909.jpg  389739.jpg	 945791.jpg
# 1606596.jpg  2172600.jpg  2765887.jpg  332557.jpg   3916407.jpg  947877.jpg
# 1615395.jpg  2173084.jpg  2768451.jpg  3326734.jpg  393349.jpg	 952407.jpg
# 1618011.jpg  217996.jpg   2771149.jpg  3330642.jpg  393494.jpg	 952437.jpg
# 1619357.jpg  2193684.jpg  2779040.jpg  3333128.jpg  398288.jpg	 955466.jpg
# 1621763.jpg  220341.jpg   2788312.jpg  3333735.jpg  40094.jpg	 9555.jpg
# 1623325.jpg  22080.jpg	  2788759.jpg  3334973.jpg  401094.jpg	 961341.jpg
# 1624450.jpg  2216146.jpg  2796102.jpg  3335013.jpg  401144.jpg	 97656.jpg
# 1624747.jpg  2222018.jpg  280284.jpg   3335267.jpg  401651.jpg	 979110.jpg
# 1628861.jpg  2223787.jpg  2807888.jpg  3346787.jpg  405173.jpg	 980247.jpg
# 1632774.jpg  2230959.jpg  2815172.jpg  3364420.jpg  405794.jpg	 982988.jpg
# 1636831.jpg  2232310.jpg  2818805.jpg  336637.jpg   40762.jpg	 987732.jpg
# 1645470.jpg  2233395.jpg  2823872.jpg  3372616.jpg  413325.jpg	 996684.jpg

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("pizza_steak"):
  print(f"There are {len(dirnames)} directory and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directory and 0 images in 'pizza_steak'.
# There are 2 directory and 0 images in 'pizza_steak/test'.
# There are 0 directory and 250 images in 'pizza_steak/test/pizza'.
# There are 0 directory and 250 images in 'pizza_steak/test/steak'.
# There are 2 directory and 0 images in 'pizza_steak/train'.
# There are 0 directory and 750 images in 'pizza_steak/train/pizza'.
# There are 0 directory and 750 images in 'pizza_steak/train/steak'.

# %% [markdown]
# To visualize our images, first let's get the class names programmatically.

# %%
# Get the classnames programmatically
import pathlib
import numpy as np
data_dir = pathlib.Path("pizza_steak/train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")])) # Created a list of class names from the subdirectories
print(class_names)
# Out:
# ['pizza' 'steak']

# %%
# Let's visualize our images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup the target directory (we'll view images from here)
  target_folder = target_dir + "/" + target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)
  print(random_image)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir="pizza_steak/train",
                        target_class="pizza")
# Out:
# ['3822139.jpg']
# Image shape: (512, 512, 3)

# %%
import tensorflow as tf
tf.constant(img, dtype="float32")
# Out:
# <tf.Tensor: shape=(512, 512, 3), dtype=float32, numpy=
# array([[[244., 189., 158.],
#         [244., 189., 158.],
#         [244., 189., 158.],
#         ...,
#         [ 63.,  31.,  18.],
#         [ 58.,  26.,  13.],
#         [ 65.,  33.,  20.]],
#
#        [[247., 192., 161.],
#         [247., 192., 161.],
#         [247., 192., 161.],
#         ...,
#         [102.,  70.,  57.],
#         [ 82.,  50.,  37.],
#         [ 65.,  33.,  20.]],
#
#        [[251., 196., 165.],
#         [251., 196., 165.],
#         [251., 196., 165.],
#         ...,
#         [119.,  87.,  76.],
#         [ 93.,  61.,  50.],
#         [ 73.,  41.,  30.]],
#
#        ...,
#
#        [[237., 181., 148.],
#         [236., 180., 147.],
#         [234., 178., 145.],
#         ...,
#         [248., 199., 158.],
#         [251., 202., 161.],
#         [248., 199., 158.]],
#
#        [[241., 185., 152.],
#         [242., 186., 153.],
#         [241., 185., 152.],
#         ...,
#         [233., 184., 143.],
#         [239., 190., 149.],
#         [236., 187., 146.]],
#
#        [[235., 176., 144.],
#         [240., 181., 149.],
#         [242., 183., 149.],
#         ...,
#         [244., 195., 154.],
#         [253., 204., 163.],
#         [251., 202., 161.]]], dtype=float32)>

# %%
# View the image shape
print(f"{img.shape[0]} width, {img.shape[1]} height and {img.shape[2]} channels")
# Out:
# 512 width, 512 height and 3 channels

# %% [markdown]
# >🔑 **Note:** As we've discussed before, many machine learning models, including neural networks prefer the values they work with to be between 0 and 1. Knowing this, one of the most common preprocessing steps for working with images is to **scale** (also referred to as **normalize**) thier pixel values by dividing the image arrays by 255. (since 255 is the maximum pixel value).

# %% [markdown]
# ## An end-to-end example
#
# Let's build a convolutional neural network to find patterns in our images, more specifically we need a way to:
# * Load our images
# * Preprocess our images
# * Build a CNN to find patterns in our images
# * Compile our CNN
# * Fit the CNN to our training data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras import layers

# Set the seed
tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 0 & 1, also called scaling/normalization)
train_datagen = ImageDataGenerator(rescale=1/255.)
valid_datagen = ImageDataGenerator(rescale=1/255.)

# Setup paths to our data directories
train_dir = "pizza_steak/train"
test_dir = "pizza_steak/test"

# Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(directory=train_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)

valid_data = valid_datagen.flow_from_directory(directory=test_dir,
                                               batch_size=32,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               seed=42)

# Build a CNN model 
inputs = keras.Input(shape=(224, 224, 3))
x = layers.Conv2D(filters=10, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(10, 3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2, padding="valid")(x)
x = layers.Conv2D(10, 3, activation="relu")(x)
x = layers.Conv2D(10, 3, activation="relu")(x)
x = layers.MaxPool2D(pool_size=2, padding="valid")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# Compile the CNN model
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# Fit the model
history = model.fit(train_data, 
          epochs=10,
          steps_per_epoch=len(train_data),
          validation_data=valid_data,
          validation_steps=len(valid_data))
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Epoch 1/10
# 47/47 [==============================] - 23s 234ms/step - loss: 0.6061 - accuracy: 0.6753 - val_loss: 0.4393 - val_accuracy: 0.8340
# Epoch 2/10
# 47/47 [==============================] - 9s 184ms/step - loss: 0.4716 - accuracy: 0.7827 - val_loss: 0.3639 - val_accuracy: 0.8760
# Epoch 3/10
# 47/47 [==============================] - 9s 197ms/step - loss: 0.4282 - accuracy: 0.8173 - val_loss: 0.3616 - val_accuracy: 0.8560
# Epoch 4/10
# 47/47 [==============================] - 9s 183ms/step - loss: 0.4004 - accuracy: 0.8340 - val_loss: 0.4366 - val_accuracy: 0.7960
# Epoch 5/10
# 47/47 [==============================] - 9s 183ms/step - loss: 0.3806 - accuracy: 0.8373 - val_loss: 0.3159 - val_accuracy: 0.8700
# Epoch 6/10
# 47/47 [==============================] - 9s 185ms/step - loss: 0.3600 - accuracy: 0.8433 - val_loss: 0.3401 - val_accuracy: 0.8500
# Epoch 7/10
# 47/47 [==============================] - 9s 186ms/step - loss: 0.3321 - accuracy: 0.8653 - val_loss: 0.3474 - val_accuracy: 0.8560
# Epoch 8/10
# 47/47 [==============================] - 9s 184ms/step - loss: 0.3084 - accuracy: 0.8760 - val_loss: 0.3072 - val_accuracy: 0.8620
# Epoch 9/10
# 47/47 [==============================] - 10s 206ms/step - loss: 0.2880 - accuracy: 0.8813 - val_loss: 0.3638 - val_accuracy: 0.8380
# Epoch 10/10
# 47/47 [==============================] - 9s 186ms/step - loss: 0.2501 - accuracy: 0.9040 - val_loss: 0.3381 - val_accuracy: 0.8620

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 1)                 28091
#
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Replicate using the fully connected layers model

# %%
# Set random seed
tf.random.set_seed(42)

# Build the model to replicate 
model_2 = keras.models.Sequential([
    layers.Flatten(input_shape=(224, 224, 3)),
    layers.Dense(4, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_2.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

# Fit the model
history_2 = model_2.fit(train_data,
            epochs=5,
            steps_per_epoch=len(train_data),
            validation_data=valid_data,
            validation_steps=len(valid_data))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 9s 177ms/step - loss: 0.7691 - accuracy: 0.5133 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/5
# 47/47 [==============================] - 8s 170ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/5
# 47/47 [==============================] - 8s 170ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 4/5
# 47/47 [==============================] - 9s 191ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/5
# 47/47 [==============================] - 8s 170ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000

# %%
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 150528)            0
#
#  dense_1 (Dense)             (None, 4)                 602116
#
#  dense_2 (Dense)             (None, 4)                 20
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 602,141
# Trainable params: 602,141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Despite having 20x more parameters than the CNN model the Fully connected layer is dead in the water.

# %% [markdown]
# ## Binary Classification: Let's break it down
#
# 1. Become one with the data (visualize, visualize, visualize)
# 2. Preprocess the data (prepared it for our model, the main step here was scaling/normalizing)
# 3. Created a model (start with a bseline)
# 4. Fit the model
# 5. Evaluate the model
# 6. Adjust difference parameters and improve the model (try to beat our baseline)
# 7. Repeat until satisfied (experiment, experiment, experiment)

# %% [markdown]
# ### 1. Become one with the data

# %%
# Visualize the data
plt.figure()
plt.subplot(1, 2, 1)
steak_img = view_random_image("pizza_steak/train", "steak")

plt.subplot(1, 2, 2)
pizza_img = view_random_image("pizza_steak/train", "pizza")
plt.show()
# Out:
# ['3577618.jpg']
# Image shape: (512, 512, 3)
# ['1998483.jpg']
# Image shape: (512, 512, 3)

# %% [markdown]
# ### 2. Preprocess the data (prepare it for a model)

# %%
# Define directory dataset paths
train_dir = "pizza_steak/train"
test_dir = "pizza_steak/test"

# %% [markdown]
# Our next step is to turn our data into **batches**.
#
# A batch is a small subset of a data. Rather than look at all - 10000 images at one time which can clog up the memory, a model might only look at 32 images at a time.
#
# It does this for a couple of reasons:
# 1. 10,000 images (or more) might not fit into the memmory of your processor (GPU).
# 2. Trying to learn the patterns in 10,000 images in one hit could result in the model not being able to learn very well.
#
# Why 32?
#
# Because 32 is good for your health... LeCun

# %%
# !nvidia-smi
# Out:
# Fri Feb  3 13:24:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Create train and test data generatrs and rescale the data
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
# Load in our image data from directories and turn them into batches
train_data = train_datagen.flow_from_directory(directory=train_dir,
                                               target_size=(224, 224),
                                               class_mode="binary",
                                               batch_size=32)

test_data = test_datagen.flow_from_directory(directory=test_dir,
                                             target_size=(224, 224),
                                             class_mode="binary",
                                             batch_size=32)
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
# Get a sample of a train data batch
images, labels = train_data.next() 
len(images), len(labels)
# Out:
# (32, 32)

# %%
# How many batches are there?
len(train_data)
# Out:
# 47

# %%
# We have 47 mini-batches and each batch contain 32 images
1500/32
# Out:
# 46.875

# %% [markdown]
# ### 3. Create a CNN model (start with a baseline)
#
# A baseline is a relatively simple model or existing result that you setup when beginning a machine learning experiment and then as you keep experimenting, you try to beat the baseline.
#
# >🔑 **Note:** In deep learning, there is almost an infiniite amount of architecture you could create. So one of the best ways to get started is to start with something simple and see if it works on your data and then introduce complexity as required (e.g. look at which current model is performing best in the field for your problem).

# %%
# Create the model (this will be our baseline, a three layer convolutional neural network)
from tensorflow.keras import layers
from tensorflow import keras

inputs = layers.Input(shape=(224, 224, 3))
x = layers.Conv2D(filters=10, kernel_size=(3, 3), strides=1, activation="relu", padding="valid")(inputs)
x = layers.Conv2D(filters=10, kernel_size=(3, 3), activation="relu")(x)
x = layers.Conv2D(filters=10, kernel_size=(3, 3), activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model_4 = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_4.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  conv2d_2 (Conv2D)           (None, 218, 218, 10)      910
#
#  flatten (Flatten)           (None, 475240)            0
#
#  dense (Dense)               (None, 1)                 475241
#
# =================================================================
# Total params: 477,341
# Trainable params: 477,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_4.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

# Fit the mode
history_4 = model_4.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 19s 220ms/step - loss: 0.8857 - accuracy: 0.6153 - val_loss: 0.6365 - val_accuracy: 0.5960
# Epoch 2/5
# 47/47 [==============================] - 9s 188ms/step - loss: 0.5732 - accuracy: 0.7113 - val_loss: 0.4395 - val_accuracy: 0.7860
# Epoch 3/5
# 47/47 [==============================] - 9s 184ms/step - loss: 0.4050 - accuracy: 0.8213 - val_loss: 0.4137 - val_accuracy: 0.8340
# Epoch 4/5
# 47/47 [==============================] - 12s 254ms/step - loss: 0.2826 - accuracy: 0.8853 - val_loss: 0.3883 - val_accuracy: 0.8400
# Epoch 5/5
# 47/47 [==============================] - 9s 186ms/step - loss: 0.1139 - accuracy: 0.9640 - val_loss: 0.4525 - val_accuracy: 0.8040

# %%
# Evaluate the model
# Let's plot the loss curves
import pandas as pd
pd.DataFrame(history_4.history).plot(figsize=(10, 7));

# %%
# Plot the validation and training curves separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """
  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["accuracy"]
  val_accuracy = history.history["val_accuracy"]

  epochs = range(len(loss)) # how many epochs did we run for?

  # Plot loss
  plt.plot(epochs, loss, label="training_loss")
  plt.plot(epochs, val_loss, label="val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()
  plt.show()
  
  # Plot accuracy
  plt.plot(epochs, accuracy, label="training_accuracy")
  plt.plot(epochs, val_accuracy, label="val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()
  plt.show()

# %%
# Check out the loss & accuracy of model_4
plot_loss_curves(history_4)

# %% [markdown]
# >🔑 **Note:** When a model's **validation loss starts to increase**, it's likely that the model is **overfitting** the training dataset. This means, it's learning the patterns in the traning dataset *too well* and thus the model's ability to generalize to unseen data will be diminished.

# %% [markdown]
# ### Adjust the model parameters
#
# Fitting a machine learning model comes in 3 steps:
#
# 0. Create a baseline
# 1. Beat the baseline by overfitting a larger model
# 2. Reduce overfitting
#
# Ways to induce overfitting:
#
# * Increase the number of conv layers
# * Increase the number of conv filters
# * Add another dense layer to the output of our flattened layer
# * Increase the number of epochs
#
# Ways to reduce overfitting:
#
# * Add data augmentation
# * Add regularization (such as MaxPooling2D)
# * Add more data
#
# >🔑 **Note:** Reducing overfitting is also known as *regularization*.

# %%
# Create the model (this is going to be our new baseline)
inputs = layers.Input(shape=(224, 224, 3))
x = layers.Conv2D(10, 3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(10, 3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(10, 3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model_5 = keras.Model(inputs=inputs, outputs=outputs)

# %%
# Compile the model
model_5.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

# Fit the model
history_5 = model_5.fit(train_data,
                        epochs=5,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 10s 204ms/step - loss: 0.5880 - accuracy: 0.6727 - val_loss: 0.4502 - val_accuracy: 0.8140
# Epoch 2/5
# 47/47 [==============================] - 11s 237ms/step - loss: 0.4794 - accuracy: 0.7787 - val_loss: 0.4253 - val_accuracy: 0.8400
# Epoch 3/5
# 47/47 [==============================] - 12s 262ms/step - loss: 0.4450 - accuracy: 0.8040 - val_loss: 0.3879 - val_accuracy: 0.8440
# Epoch 4/5
# 47/47 [==============================] - 11s 238ms/step - loss: 0.4250 - accuracy: 0.8180 - val_loss: 0.3709 - val_accuracy: 0.8440
# Epoch 5/5
# 47/47 [==============================] - 11s 236ms/step - loss: 0.3969 - accuracy: 0.8287 - val_loss: 0.3585 - val_accuracy: 0.8580

# %%
# Get a summary
model_5.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_3 (Conv2D)           (None, 222, 222, 10)      280
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 10)     0
#  )
#
#  conv2d_4 (Conv2D)           (None, 109, 109, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 52, 52, 10)        910
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 10)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6760)              0
#
#  dense_1 (Dense)             (None, 1)                 6761
#
# =================================================================
# Total params: 8,861
# Trainable params: 8,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot loss curves
plot_loss_curves(history_5)

# %% [markdown]
# ### Opening our bag of tricks and finding data augmentation

# %%
# Create ImageDataGenerator training instance with data augmentation
train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=0.2,
                                             shear_range=0.2,
                                             zoom_range=0.2,
                                             width_shift_range=0.2,
                                             height_shift_range=0.3,
                                             horizontal_flip=True)

# Create ImageDataGenerator without data augmentation
train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %% [markdown]
# >🤔 **Question:** What is data augmentation?
#
# Data augmentation is the process of altering our training data, leading it to have more diversity and in turn allowing our models to learn more generalizable (hopefully) patterns. Altering might mean adjusting the rotation of an image, flipping it, cropping it, or something similar.

# %%
# Import data and augment it from traning directory
print("Augmented training data:")
train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                                                   target_size=(224, 224),
                                                                   batch_size=32,
                                                                   class_mode="binary")
# Create non-augmented train data batches
print("Non-augmented training data:")
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode="binary")

# Create non-augmenting test data batches
print("Non-augmented test data:")
test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=(224, 224),
                                             batch_size=32,
                                             class_mode="binary")
# Out:
# Augmented training data:
# Found 1500 images belonging to 2 classes.
# Non-augmented training data:
# Found 1500 images belonging to 2 classes.
# Non-augmented test data:
# Found 500 images belonging to 2 classes.

# %% [markdown]
# > 🔑 **Note:** Data augmentation is usually only performed on the training data. Using `ImageDataGenerator` built-in data augmentation parameters our images are left as they are in the directories but are modified as they're loaded into the model.

# %%
# Get sample data batches
images, labels = train_data.next()
augmented_images, augmented_labels = train_data_augmented.next()

# %%
# Show original image and augmented image
import random
random_number = random.randint(0, 31) 
plt.imshow(images[random_number])
plt.title("Original image")
plt.axis(False)
plt.figure()
plt.imshow(augmented_images[random_number])
plt.title("Augmented image")
plt.axis(False);

# %%
# Create the model
from tensorflow import keras
inputs = keras.Input(shape=(224, 224, 3))
x = keras.layers.Conv2D(10, 3, activation="relu")(inputs)
x = keras.layers.MaxPooling2D(pool_size=2)(x)
x = keras.layers.Conv2D(10, 3, activation="relu")(x)
x = keras.layers.MaxPooling2D(pool_size=2)(x)
x = keras.layers.Conv2D(10, 3, activation="relu")(x)
x = keras.layers.MaxPooling2D(pool_size=2)(x)
x = keras.layers.Flatten()(x)
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model_6 = keras.Model(inputs, outputs)

# %%
model_6.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d_6 (Conv2D)           (None, 222, 222, 10)      280
#
#  max_pooling2d_3 (MaxPooling  (None, 111, 111, 10)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 109, 109, 10)      910
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 52, 52, 10)        910
#
#  max_pooling2d_5 (MaxPooling  (None, 26, 26, 10)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6760)              0
#
#  dense_2 (Dense)             (None, 1)                 6761
#
# =================================================================
# Total params: 8,861
# Trainable params: 8,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_6.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

# Fit the model
history_6 = model_6.fit(train_data_augmented,
                        epochs=5,
                        steps_per_epoch=len(train_data_augmented),
                        validation_data=test_data,
                        validation_steps=(len(test_data)))
# Out:
# Epoch 1/5
# 47/47 [==============================] - 29s 594ms/step - loss: 0.6525 - accuracy: 0.5993 - val_loss: 0.5166 - val_accuracy: 0.8040
# Epoch 2/5
# 47/47 [==============================] - 23s 495ms/step - loss: 0.5286 - accuracy: 0.7333 - val_loss: 0.3814 - val_accuracy: 0.8440
# Epoch 3/5
# 47/47 [==============================] - 28s 605ms/step - loss: 0.5199 - accuracy: 0.7613 - val_loss: 0.3872 - val_accuracy: 0.8340
# Epoch 4/5
# 47/47 [==============================] - 22s 476ms/step - loss: 0.5069 - accuracy: 0.7593 - val_loss: 0.4440 - val_accuracy: 0.7820
# Epoch 5/5
# 47/47 [==============================] - 21s 445ms/step - loss: 0.4941 - accuracy: 0.7620 - val_loss: 0.3542 - val_accuracy: 0.8580

# %%
# Evalute the model
plot_loss_curves(history_6)

# %%
# Using data augmentation
from tensorflow.keras import layers
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2)
])

# Defining a new convnet with image augmentation and dropout
inputs = layers.Input(shape=(224, 224, 3))
x = data_augmentation(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model_7 = keras.Model(inputs=inputs, outputs=outputs)

# Compile the model
model_7.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy"])

# Fit the model
history_7 = model_7.fit(train_data,
            epochs=10,
            validation_data=test_data)
# Out:
# Epoch 1/10
# 47/47 [==============================] - 19s 354ms/step - loss: 0.6741 - accuracy: 0.5867 - val_loss: 0.5637 - val_accuracy: 0.6940
# Epoch 2/10
# 47/47 [==============================] - 12s 258ms/step - loss: 0.5395 - accuracy: 0.7547 - val_loss: 0.3920 - val_accuracy: 0.8500
# Epoch 3/10
# 47/47 [==============================] - 10s 204ms/step - loss: 0.4671 - accuracy: 0.7987 - val_loss: 0.3675 - val_accuracy: 0.8640
# Epoch 4/10
# 47/47 [==============================] - 10s 201ms/step - loss: 0.4435 - accuracy: 0.8027 - val_loss: 0.3473 - val_accuracy: 0.8640
# Epoch 5/10
# 47/47 [==============================] - 15s 312ms/step - loss: 0.4223 - accuracy: 0.8140 - val_loss: 0.3757 - val_accuracy: 0.8460
# Epoch 6/10
# 47/47 [==============================] - 11s 232ms/step - loss: 0.3985 - accuracy: 0.8327 - val_loss: 0.5162 - val_accuracy: 0.7980
# Epoch 7/10
# 47/47 [==============================] - 10s 203ms/step - loss: 0.4008 - accuracy: 0.8300 - val_loss: 0.3766 - val_accuracy: 0.8560
# Epoch 8/10
# 47/47 [==============================] - 10s 213ms/step - loss: 0.3848 - accuracy: 0.8353 - val_loss: 0.2854 - val_accuracy: 0.8840
# Epoch 9/10
# 47/47 [==============================] - 16s 345ms/step - loss: 0.3489 - accuracy: 0.8560 - val_loss: 0.3679 - val_accuracy: 0.8520
# Epoch 10/10
# 47/47 [==============================] - 10s 203ms/step - loss: 0.3434 - accuracy: 0.8547 - val_loss: 0.3352 - val_accuracy: 0.8940

# %%
# Plot loss curves
plot_loss_curves(history_7)

# %%
# View our example image
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/03-steak.jpeg 
steak = mpimg.imread("03-steak.jpeg")
plt.imshow(steak)
plt.axis(False);
# Out:
# --2023-02-03 13:31:17--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/03-steak.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1978213 (1.9M) [image/jpeg]
# Saving to: ‘03-steak.jpeg’
#
# 03-steak.jpeg       100%[===================>]   1.89M  --.-KB/s    in 0.06s
#
# 2023-02-03 13:31:17 (31.3 MB/s) - ‘03-steak.jpeg’ saved [1978213/1978213]

# %%
# Check the shape of our image
steak.shape
# Out:
# (4032, 3024, 3)

# %%
# Create a function to import an image and resize it to be able to be used with our model
import tensorflow as tf

def load_and_prep_image(filename, img_shape=180):
  """
  Reads an image from filename, turns it 
  into a tensor and reshapes it to 
  (img_shape, img_shape, color_channels)
  """
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode the read_file into a tensor
  img = tf.image.decode_image(img)
  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  return img

# %%
# Load in and preprocess our custom image
steak = load_and_prep_image("03-steak.jpeg")
steak
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.6377451 , 0.6220588 , 0.57892156],
#         [0.6504902 , 0.63186276, 0.5897059 ],
#         [0.63186276, 0.60833335, 0.5612745 ],
#         ...,
#         [0.52156866, 0.05098039, 0.09019608],
#         [0.49509802, 0.04215686, 0.07058824],
#         [0.52843136, 0.07745098, 0.10490196]],
#
#        [[0.6617647 , 0.6460784 , 0.6107843 ],
#         [0.6387255 , 0.6230392 , 0.57598037],
#         [0.65588236, 0.63235295, 0.5852941 ],
#         ...,
#         [0.5352941 , 0.06862745, 0.09215686],
#         [0.529902  , 0.05931373, 0.09460784],
#         [0.5142157 , 0.05539216, 0.08676471]],
#
#        [[0.6519608 , 0.6362745 , 0.5892157 ],
#         [0.6392157 , 0.6137255 , 0.56764704],
#         [0.65637255, 0.6269608 , 0.5828431 ],
#         ...,
#         [0.53137255, 0.06470589, 0.08039216],
#         [0.527451  , 0.06862745, 0.1       ],
#         [0.52254903, 0.05196078, 0.0872549 ]],
#
#        ...,
#
#        [[0.49313724, 0.42745098, 0.31029412],
#         [0.05441177, 0.01911765, 0.        ],
#         [0.2127451 , 0.16176471, 0.09509804],
#         ...,
#         [0.6132353 , 0.59362745, 0.57009804],
#         [0.65294117, 0.6333333 , 0.6098039 ],
#         [0.64166665, 0.62990195, 0.59460783]],
#
#        [[0.65392154, 0.5715686 , 0.45      ],
#         [0.6367647 , 0.54656863, 0.425     ],
#         [0.04656863, 0.01372549, 0.        ],
#         ...,
#         [0.6372549 , 0.61764705, 0.59411764],
#         [0.63529414, 0.6215686 , 0.5892157 ],
#         [0.6401961 , 0.62058824, 0.59705883]],
#
#        [[0.1       , 0.05539216, 0.        ],
#         [0.48333332, 0.40882352, 0.29117647],
#         [0.65      , 0.5686275 , 0.44019607],
#         ...,
#         [0.6308824 , 0.6161765 , 0.5808824 ],
#         [0.6519608 , 0.63186276, 0.5901961 ],
#         [0.6338235 , 0.6259804 , 0.57892156]]], dtype=float32)>

# %%
tf.expand_dims(steak, axis=0)
# Out:
# <tf.Tensor: shape=(1, 224, 224, 3), dtype=float32, numpy=
# array([[[[0.6377451 , 0.6220588 , 0.57892156],
#          [0.6504902 , 0.63186276, 0.5897059 ],
#          [0.63186276, 0.60833335, 0.5612745 ],
#          ...,
#          [0.52156866, 0.05098039, 0.09019608],
#          [0.49509802, 0.04215686, 0.07058824],
#          [0.52843136, 0.07745098, 0.10490196]],
#
#         [[0.6617647 , 0.6460784 , 0.6107843 ],
#          [0.6387255 , 0.6230392 , 0.57598037],
#          [0.65588236, 0.63235295, 0.5852941 ],
#          ...,
#          [0.5352941 , 0.06862745, 0.09215686],
#          [0.529902  , 0.05931373, 0.09460784],
#          [0.5142157 , 0.05539216, 0.08676471]],
#
#         [[0.6519608 , 0.6362745 , 0.5892157 ],
#          [0.6392157 , 0.6137255 , 0.56764704],
#          [0.65637255, 0.6269608 , 0.5828431 ],
#          ...,
#          [0.53137255, 0.06470589, 0.08039216],
#          [0.527451  , 0.06862745, 0.1       ],
#          [0.52254903, 0.05196078, 0.0872549 ]],
#
#         ...,
#
#         [[0.49313724, 0.42745098, 0.31029412],
#          [0.05441177, 0.01911765, 0.        ],
#          [0.2127451 , 0.16176471, 0.09509804],
#          ...,
#          [0.6132353 , 0.59362745, 0.57009804],
#          [0.65294117, 0.6333333 , 0.6098039 ],
#          [0.64166665, 0.62990195, 0.59460783]],
#
#         [[0.65392154, 0.5715686 , 0.45      ],
#          [0.6367647 , 0.54656863, 0.425     ],
#          [0.04656863, 0.01372549, 0.        ],
#          ...,
#          [0.6372549 , 0.61764705, 0.59411764],
#          [0.63529414, 0.6215686 , 0.5892157 ],
#          [0.6401961 , 0.62058824, 0.59705883]],
#
#         [[0.1       , 0.05539216, 0.        ],
#          [0.48333332, 0.40882352, 0.29117647],
#          [0.65      , 0.5686275 , 0.44019607],
#          ...,
#          [0.6308824 , 0.6161765 , 0.5808824 ],
#          [0.6519608 , 0.63186276, 0.5901961 ],
#          [0.6338235 , 0.6259804 , 0.57892156]]]], dtype=float32)>

# %%
model_7.predict(tf.expand_dims(steak, axis=0))
# Out:
# 1/1 [==============================] - 0s 90ms/step
# array([[0.82000697]], dtype=float32)

# %%
# We can index the predicted class by rounding the prediction probability and indexing it on the class names
pred_class = class_names[int(tf.round(model_7.predict(tf.expand_dims(steak, axis=0))))]
pred_class
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 'steak'

# %%
def pred_and_plot(model, filename, class_names=class_names):
  """
  Imports an image located at filenames, makes a prediction 
  with model and plots the image with the predicted class as 
  the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  pred_class = class_names[int(tf.round(pred))]

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);

# %%
# Test our model on a custom image
pred_and_plot(model_7, "03-steak.jpeg")
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# Nice! Our model got the prediction right.
#
# Let's try one more image.

# %%
# Download another test image and make a prediction on it
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/images/03-pizza-dad.jpeg 
pred_and_plot(model_7, "03-steak.jpeg", class_names)

# %% [markdown]
# # Multiclass Image Classification
#
# 1. Become one with the data
# 2. Preprocess the data (get it ready for a model)
# 3. Create a model (start with a baseline)
# 4. Fit the model (overfit it to make sure it works)
# 5. Evaluate the model
# 6. Adjust different hyperparameters and improve the model (try to beat baseline/reduce overfitting)
# 7. Repeat until satisfied

# %% [markdown]
# ## 1. Import and become one with the data

# %%
import zipfile

# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_all_data.zip

# Unzip the downloaded file
zip_ref = zipfile.ZipFile("10_food_classes_all_data.zip")
zip_ref.extractall()
zip_ref.close()
# Out:
# --2023-02-03 16:51:52--  https://storage.googleapis.com/ztm_tf_course/food_vision/10_food_classes_all_data.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.145.128, 74.125.143.128, 108.177.96.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.145.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 519183241 (495M) [application/zip]
# Saving to: ‘10_food_classes_all_data.zip.1’
#
# 10_food_classes_all 100%[===================>] 495.13M  41.5MB/s    in 13s
#
# 2023-02-03 16:52:05 (39.3 MB/s) - ‘10_food_classes_all_data.zip.1’ saved [519183241/519183241]

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("10_food_classes_all_data"):
  print(f"There are {len(dirnames)} directory and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directory and 0 images in '10_food_classes_all_data'.
# There are 10 directory and 0 images in '10_food_classes_all_data/test'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/sushi'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/pizza'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/hamburger'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/chicken_wings'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/chicken_curry'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/ramen'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/ice_cream'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/fried_rice'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/steak'.
# There are 0 directory and 250 images in '10_food_classes_all_data/test/grilled_salmon'.
# There are 10 directory and 0 images in '10_food_classes_all_data/train'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/sushi'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/pizza'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/hamburger'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/chicken_wings'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/chicken_curry'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/ramen'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/ice_cream'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/fried_rice'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/steak'.
# There are 0 directory and 750 images in '10_food_classes_all_data/train/grilled_salmon'.

# %%
# Get the classnames programmatically
import pathlib
import numpy as np
data_dir = pathlib.Path("10_food_classes_all_data/train")
test_dir = pathlib.Path("10_food_classes_all_data/test")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")])) # Created a list of class names from the subdirectories
print(class_names)
# Out:
# ['chicken_curry' 'chicken_wings' 'fried_rice' 'grilled_salmon' 'hamburger'
#  'ice_cream' 'pizza' 'ramen' 'steak' 'sushi']

# %%
# Let's visualize our images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup the target directory (we'll view images from here)
  target_folder = target_dir + "/" + target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)
  print(random_image)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir="10_food_classes_all_data/train",
                        target_class="grilled_salmon")
# Out:
# ['2589931.jpg']
# Image shape: (384, 512, 3)

# %% [markdown]
# ## An end-to-end example
#
# Let's build a convolutional neural network to find patterns in our images, more specifically we need a way to:
# * Load our images
# * Preprocess our images
# * Build a CNN to find patterns in our images
# * Compile our CNN
# * Fit the CNN to our training data

# %%
# Using image_dataset_from_directory to read immages
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(data_dir,
                                             image_size=(180, 180),
                                             batch_size=32,
                                             shuffle=True)
test_dataset = image_dataset_from_directory(test_dir,
                                            image_size=(180, 180),
                                            batch_size=32,
                                             shuffle=True)
# Out:
# Found 7500 files belonging to 10 classes.
# Found 2500 files belonging to 10 classes.

# %%
for data_batch, labels_batch in train_dataset:
  print("data batch shape:", data_batch.shape)
  print("labels batch shape:", labels_batch.shape)
  break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %%
# Instantiating a simple CNN model
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(64, 3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(128, 3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(len(class_names), activation="softmax")(x)
model = keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  conv2d_48 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_27 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_28 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 41, 41, 128)       73856
#
#  flatten_6 (Flatten)         (None, 215168)            0
#
#  dense_5 (Dense)             (None, 10)                2151690
#
# =================================================================
# Total params: 2,244,938
# Trainable params: 2,244,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

# Fit the model
history = model.fit(train_dataset,
                    epochs=20,
                    validation_data=test_dataset,
                    callbacks=callbacks)
# Out:
# Epoch 1/20
# 235/235 [==============================] - 20s 78ms/step - loss: 6.7821 - accuracy: 0.1513 - val_loss: 2.3129 - val_accuracy: 0.1376
# Epoch 2/20
# 235/235 [==============================] - 20s 82ms/step - loss: 3.5479 - accuracy: 0.1727 - val_loss: 2.3211 - val_accuracy: 0.1200
# Epoch 3/20
# 235/235 [==============================] - 22s 91ms/step - loss: 2.5518 - accuracy: 0.2644 - val_loss: 3.7471 - val_accuracy: 0.1140
# Epoch 4/20
# 235/235 [==============================] - 28s 119ms/step - loss: 2.6142 - accuracy: 0.3836 - val_loss: 2.8281 - val_accuracy: 0.1332
# Epoch 5/20
# 235/235 [==============================] - 19s 80ms/step - loss: 1.8486 - accuracy: 0.5108 - val_loss: 3.6411 - val_accuracy: 0.1212
# Epoch 6/20
# 235/235 [==============================] - 20s 83ms/step - loss: 1.5672 - accuracy: 0.6109 - val_loss: 8.3852 - val_accuracy: 0.1336
# Epoch 7/20
# 235/235 [==============================] - 24s 100ms/step - loss: 1.3589 - accuracy: 0.6904 - val_loss: 5.8232 - val_accuracy: 0.1416
# Epoch 8/20
# 235/235 [==============================] - 27s 114ms/step - loss: 1.1800 - accuracy: 0.7683 - val_loss: 11.2957 - val_accuracy: 0.1336
# Epoch 9/20
# 235/235 [==============================] - 25s 105ms/step - loss: 1.2760 - accuracy: 0.8056 - val_loss: 11.1746 - val_accuracy: 0.1420
# Epoch 10/20
# 235/235 [==============================] - 23s 97ms/step - loss: 0.9925 - accuracy: 0.8348 - val_loss: 14.1389 - val_accuracy: 0.1400
# Epoch 11/20
# 235/235 [==============================] - 24s 100ms/step - loss: 0.8119 - accuracy: 0.8761 - val_loss: 15.2068 - val_accuracy: 0.1428
# Epoch 12/20
# 235/235 [==============================] - 28s 116ms/step - loss: 0.6731 - accuracy: 0.8985 - val_loss: 16.8699 - val_accuracy: 0.1364
# Epoch 13/20
# 235/235 [==============================] - 32s 134ms/step - loss: 0.7570 - accuracy: 0.9116 - val_loss: 20.9826 - val_accuracy: 0.1480
# Epoch 14/20
# 235/235 [==============================] - 28s 116ms/step - loss: 0.8268 - accuracy: 0.9252 - val_loss: 23.4044 - val_accuracy: 0.1464
# Epoch 15/20
# 235/235 [==============================] - 28s 115ms/step - loss: 0.8829 - accuracy: 0.9388 - val_loss: 21.3270 - val_accuracy: 0.1524
# Epoch 16/20
# 235/235 [==============================] - 25s 105ms/step - loss: 0.2572 - accuracy: 0.9539 - val_loss: 25.1069 - val_accuracy: 0.1576
# Epoch 17/20
# 235/235 [==============================] - 29s 119ms/step - loss: 0.4118 - accuracy: 0.9571 - val_loss: 29.1037 - val_accuracy: 0.1516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-3701ce2c9275> in <module>
#      12
#      13 # Fit the model
# ---> 14 history = model.fit(train_dataset,
#      15                     epochs=20,
#      16                     validation_data=test_dataset,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1395       logs = None
#    1396       for epoch, iterator in data_handler.enumerate_epochs():
# -> 1397         self.reset_metrics()
#    1398         callbacks.on_epoch_begin(epoch)
#    1399         with data_handler.catch_stop_iteration():
#
# KeyboardInterrupt:

# %%
data_augmentation = keras.Sequential(
 [
 layers.RandomFlip("horizontal"),
 layers.RandomRotation(0.1),
 layers.RandomZoom(0.2),
 ]
)

conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
conv_base.trainable = False

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="sparse_categorical_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

history = model.fit(train_dataset,
                    epochs=50,
                    validation_data=test_dataset,
                    callbacks=callbacks)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 47s 186ms/step - loss: 63.7212 - accuracy: 0.5603 - val_loss: 39.5020 - val_accuracy: 0.7352
# Epoch 2/50
# 235/235 [==============================] - 43s 180ms/step - loss: 40.9507 - accuracy: 0.6709 - val_loss: 30.9131 - val_accuracy: 0.7608
# Epoch 3/50
# 235/235 [==============================] - 42s 178ms/step - loss: 29.9065 - accuracy: 0.7067 - val_loss: 28.2872 - val_accuracy: 0.7616
# Epoch 4/50
# 235/235 [==============================] - 43s 181ms/step - loss: 23.8078 - accuracy: 0.7140 - val_loss: 21.0471 - val_accuracy: 0.7724
# Epoch 5/50
# 235/235 [==============================] - 43s 179ms/step - loss: 16.7777 - accuracy: 0.7316 - val_loss: 19.4268 - val_accuracy: 0.7548
# Epoch 6/50
# 235/235 [==============================] - 43s 180ms/step - loss: 13.1726 - accuracy: 0.7283 - val_loss: 18.9851 - val_accuracy: 0.7060
# Epoch 7/50
# 235/235 [==============================] - 42s 179ms/step - loss: 10.1812 - accuracy: 0.7316 - val_loss: 9.2163 - val_accuracy: 0.7752
# Epoch 8/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.7033 - accuracy: 0.7348 - val_loss: 8.5464 - val_accuracy: 0.7632
# Epoch 9/50
# 235/235 [==============================] - 43s 180ms/step - loss: 6.9496 - accuracy: 0.7376 - val_loss: 9.7832 - val_accuracy: 0.7344
# Epoch 10/50
# 235/235 [==============================] - 43s 181ms/step - loss: 6.5565 - accuracy: 0.7409 - val_loss: 10.1208 - val_accuracy: 0.7340
# Epoch 11/50
# 235/235 [==============================] - 43s 180ms/step - loss: 6.5249 - accuracy: 0.7456 - val_loss: 7.9960 - val_accuracy: 0.7772
# Epoch 12/50
# 235/235 [==============================] - 42s 176ms/step - loss: 6.4844 - accuracy: 0.7561 - val_loss: 8.6214 - val_accuracy: 0.7696
# Epoch 13/50
# 235/235 [==============================] - 43s 180ms/step - loss: 6.5989 - accuracy: 0.7547 - val_loss: 8.6673 - val_accuracy: 0.7668
# Epoch 14/50
# 235/235 [==============================] - 42s 179ms/step - loss: 6.7487 - accuracy: 0.7581 - val_loss: 7.3712 - val_accuracy: 0.8072
# Epoch 15/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.0112 - accuracy: 0.7547 - val_loss: 9.5955 - val_accuracy: 0.7760
# Epoch 16/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.1992 - accuracy: 0.7601 - val_loss: 8.9921 - val_accuracy: 0.7924
# Epoch 17/50
# 235/235 [==============================] - 42s 179ms/step - loss: 6.8506 - accuracy: 0.7743 - val_loss: 9.8003 - val_accuracy: 0.7792
# Epoch 18/50
# 235/235 [==============================] - 43s 183ms/step - loss: 7.2914 - accuracy: 0.7656 - val_loss: 10.3286 - val_accuracy: 0.7812
# Epoch 19/50
# 235/235 [==============================] - 43s 180ms/step - loss: 7.1521 - accuracy: 0.7727 - val_loss: 14.4262 - val_accuracy: 0.7468
# Epoch 20/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.2499 - accuracy: 0.7759 - val_loss: 10.5706 - val_accuracy: 0.7828
# Epoch 21/50
# 235/235 [==============================] - 43s 181ms/step - loss: 6.9851 - accuracy: 0.7840 - val_loss: 11.9271 - val_accuracy: 0.7744
# Epoch 22/50
# 235/235 [==============================] - 42s 178ms/step - loss: 7.3548 - accuracy: 0.7812 - val_loss: 12.0579 - val_accuracy: 0.7752
# Epoch 23/50
# 235/235 [==============================] - 43s 182ms/step - loss: 7.1531 - accuracy: 0.7931 - val_loss: 10.2103 - val_accuracy: 0.7976
# Epoch 24/50
# 235/235 [==============================] - 43s 182ms/step - loss: 7.5883 - accuracy: 0.7860 - val_loss: 10.7496 - val_accuracy: 0.7944
# Epoch 25/50
# 235/235 [==============================] - 43s 182ms/step - loss: 7.0332 - accuracy: 0.7984 - val_loss: 11.8143 - val_accuracy: 0.7920
# Epoch 26/50
# 235/235 [==============================] - 43s 182ms/step - loss: 7.0884 - accuracy: 0.7961 - val_loss: 10.8237 - val_accuracy: 0.8116
# Epoch 27/50
# 235/235 [==============================] - 43s 182ms/step - loss: 7.6181 - accuracy: 0.7967 - val_loss: 11.9792 - val_accuracy: 0.7900
# Epoch 28/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.6309 - accuracy: 0.7928 - val_loss: 13.1763 - val_accuracy: 0.7904
# Epoch 29/50
# 235/235 [==============================] - 43s 181ms/step - loss: 7.4773 - accuracy: 0.8029 - val_loss: 14.1262 - val_accuracy: 0.7816
# Epoch 30/50
# 235/235 [==============================] - 43s 183ms/step - loss: 7.8276 - accuracy: 0.8028 - val_loss: 12.8891 - val_accuracy: 0.7940
# Epoch 31/50
# 235/235 [==============================] - 42s 179ms/step - loss: 7.9980 - accuracy: 0.8072 - val_loss: 12.9264 - val_accuracy: 0.7900
# Epoch 32/50
# 235/235 [==============================] - 43s 181ms/step - loss: 7.9389 - accuracy: 0.8017 - val_loss: 14.4357 - val_accuracy: 0.7796
# Epoch 33/50
# 235/235 [==============================] - 43s 184ms/step - loss: 7.8972 - accuracy: 0.8055 - val_loss: 17.6428 - val_accuracy: 0.7532
# Epoch 34/50
# 235/235 [==============================] - 42s 177ms/step - loss: 7.7994 - accuracy: 0.8053 - val_loss: 16.0249 - val_accuracy: 0.7656
# Epoch 35/50
# 235/235 [==============================] - 43s 181ms/step - loss: 7.8375 - accuracy: 0.8121 - val_loss: 12.9793 - val_accuracy: 0.7932
# Epoch 36/50
# 235/235 [==============================] - 43s 180ms/step - loss: 7.5675 - accuracy: 0.8176 - val_loss: 13.7639 - val_accuracy: 0.7948
# Epoch 37/50
# 235/235 [==============================] - 43s 181ms/step - loss: 7.7219 - accuracy: 0.8113 - val_loss: 15.9421 - val_accuracy: 0.7740
# Epoch 38/50
# 235/235 [==============================] - 43s 180ms/step - loss: 8.2580 - accuracy: 0.8075 - val_loss: 14.2163 - val_accuracy: 0.7984
# Epoch 39/50
# 235/235 [==============================] - 42s 179ms/step - loss: 8.4666 - accuracy: 0.8101 - val_loss: 13.2196 - val_accuracy: 0.8052
# Epoch 40/50
# 235/235 [==============================] - 43s 180ms/step - loss: 8.2350 - accuracy: 0.8197 - val_loss: 14.2139 - val_accuracy: 0.7964
# Epoch 41/50
# 235/235 [==============================] - 42s 177ms/step - loss: 7.7827 - accuracy: 0.8205 - val_loss: 14.7974 - val_accuracy: 0.8016
# Epoch 42/50
# 235/235 [==============================] - 42s 177ms/step - loss: 7.7804 - accuracy: 0.8235 - val_loss: 16.2988 - val_accuracy: 0.7960
# Epoch 43/50
# 235/235 [==============================] - 43s 183ms/step - loss: 8.1524 - accuracy: 0.8240 - val_loss: 14.4037 - val_accuracy: 0.8036
# Epoch 44/50
# 235/235 [==============================] - 42s 177ms/step - loss: 8.1323 - accuracy: 0.8279 - val_loss: 14.4661 - val_accuracy: 0.8064
# Epoch 45/50
# 235/235 [==============================] - 43s 181ms/step - loss: 8.2574 - accuracy: 0.8212 - val_loss: 19.0667 - val_accuracy: 0.7884
# Epoch 46/50
# 235/235 [==============================] - 43s 180ms/step - loss: 8.0542 - accuracy: 0.8308 - val_loss: 20.0634 - val_accuracy: 0.7704
# Epoch 47/50
# 235/235 [==============================] - 42s 176ms/step - loss: 8.5449 - accuracy: 0.8269 - val_loss: 19.8238 - val_accuracy: 0.7804
# Epoch 48/50
# 235/235 [==============================] - 42s 179ms/step - loss: 8.3155 - accuracy: 0.8305 - val_loss: 14.7540 - val_accuracy: 0.8180
# Epoch 49/50
# 235/235 [==============================] - 42s 179ms/step - loss: 8.3247 - accuracy: 0.8287 - val_loss: 17.9974 - val_accuracy: 0.7960
# Epoch 50/50
# 235/235 [==============================] - 42s 178ms/step - loss: 8.6915 - accuracy: 0.8199 - val_loss: 17.0251 - val_accuracy: 0.7964

# %%
plot_loss_curves(history)

# %%
img = tf.io.read_file("Chicken-Curry-recipe.jpg")
# Decode the read_file into a tensor
img = tf.image.decode_image(img)
# Resize the image
img = tf.image.resize(img, [180, 180])
# Rescale the image (get all values between 0 and 1)
img = img/255.
img
# Out:
# <tf.Tensor: shape=(180, 180, 3), dtype=float32, numpy=
# array([[[0.13129991, 0.08816268, 0.06463326],
#         [0.1523239 , 0.08678288, 0.06935368],
#         [0.13390222, 0.09381507, 0.0687606 ],
#         ...,
#         [0.40878803, 0.32516444, 0.29377967],
#         [0.29226682, 0.20693617, 0.16474275],
#         [0.23287332, 0.15462334, 0.10912605]],
#
#        [[0.15551923, 0.10530137, 0.09197531],
#         [0.17559913, 0.13376907, 0.11089325],
#         [0.27273056, 0.21521422, 0.18841682],
#         ...,
#         [0.5636891 , 0.4872185 , 0.4512708 ],
#         [0.50914884, 0.434312  , 0.38986757],
#         [0.5014894 , 0.43155476, 0.39364624]],
#
#        [[0.2433551 , 0.1749334 , 0.1433793 ],
#         [0.37106028, 0.27236748, 0.23467684],
#         [0.36072382, 0.2735173 , 0.22101186],
#         ...,
#         [0.21344616, 0.15010816, 0.10556701],
#         [0.33384308, 0.27284092, 0.223676  ],
#         [0.2855846 , 0.22458242, 0.17687   ]],
#
#        ...,
#
#        [[0.8094766 , 0.42404965, 0.0196682 ],
#         [0.80402803, 0.4108547 , 0.02806804],
#         [0.8286634 , 0.44522074, 0.02533333],
#         ...,
#         [0.3519465 , 0.2844086 , 0.24061742],
#         [0.38289705, 0.3079153 , 0.26205498],
#         [0.33156517, 0.25858054, 0.20672888]],
#
#        [[0.8573039 , 0.47905457, 0.08112096],
#         [0.80097985, 0.4233111 , 0.01045545],
#         [0.80849856, 0.4131093 , 0.05243266],
#         ...,
#         [0.35268793, 0.2854036 , 0.22585402],
#         [0.31633827, 0.2508696 , 0.18877794],
#         [0.30196202, 0.24117722, 0.18823652]],
#
#        [[0.6704554 , 0.29869324, 0.        ],
#         [0.6846788 , 0.31060433, 0.04005214],
#         [0.67825544, 0.31485656, 0.03980581],
#         ...,
#         [0.46073484, 0.37274164, 0.30889508],
#         [0.50831455, 0.41757384, 0.35501027],
#         [0.45309937, 0.36573532, 0.31083336]]], dtype=float32)>

# %%
pred = model.predict(tf.expand_dims(img, axis=0))
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
class_names[np.argmax(pred)]
# Out:
# 'chicken_wings'

# %%
# Download another test image and make a prediction on it
# !wget https://recipesofhome.com/wp-content/uploads/2020/06/veg-fried-rice-recipe.jpg
# Out:
# --2023-02-03 19:32:31--  https://recipesofhome.com/wp-content/uploads/2020/06/veg-fried-rice-recipe.jpg
# Resolving recipesofhome.com (recipesofhome.com)... 172.67.204.172, 104.21.61.9, 2a06:98c1:3121::, ...
# Connecting to recipesofhome.com (recipesofhome.com)|172.67.204.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘veg-fried-rice-recipe.jpg.1’
#
# veg-fried-rice-reci     [ <=>                ]  81.75K  --.-KB/s    in 0.01s
#
# 2023-02-03 19:32:31 (7.58 MB/s) - ‘veg-fried-rice-recipe.jpg.1’ saved [83707]

# %%
img = tf.io.read_file("51089680.cms")
# Decode the read_file into a tensor
img = tf.image.decode_image(img)
# Resize the image
img = tf.image.resize(img, [180, 180])
# Rescale the image (get all values between 0 and 1)
img = img/255.
img
# Out:
# <tf.Tensor: shape=(180, 180, 3), dtype=float32, numpy=
# array([[[0.6594553 , 0.79709446, 0.06596163],
#         [0.6293391 , 0.8008896 , 0.05017247],
#         [0.56590414, 0.74284977, 0.0025121 ],
#         ...,
#         [0.9479455 , 0.24333365, 0.05103507],
#         [0.9581332 , 0.21242261, 0.03103068],
#         [0.934221  , 0.19385152, 0.02037816]],
#
#        [[0.57631993, 0.7176616 , 0.09359659],
#         [0.5441122 , 0.69405776, 0.10372549],
#         [0.4728014 , 0.62376   , 0.04281227],
#         ...,
#         [0.94648343, 0.2121009 , 0.03027254],
#         [0.9488681 , 0.1864709 , 0.01418876],
#         [0.9143575 , 0.19106732, 0.04085653]],
#
#        [[0.49063182, 0.6238017 , 0.0914488 ],
#         [0.44806647, 0.60193354, 0.075118  ],
#         [0.43765736, 0.5531802 , 0.06380114],
#         ...,
#         [0.9382355 , 0.1892159 , 0.02451002],
#         [0.9293757 , 0.18035609, 0.01434333],
#         [0.91279954, 0.18972054, 0.03827404]],
#
#        ...,
#
#        [[0.7723329 , 0.7723329 , 0.74096036],
#         [0.7921569 , 0.7923388 , 0.7617377 ],
#         [0.8175379 , 0.8177562 , 0.78730947],
#         ...,
#         [0.49203095, 0.33792466, 0.20731424],
#         [0.46904752, 0.34486514, 0.24078788],
#         [0.4112209 , 0.27788755, 0.17300124]],
#
#        [[0.90370685, 0.8997853 , 0.8914845 ],
#         [0.8651951 , 0.86993337, 0.858746  ],
#         [0.88844794, 0.89491814, 0.88315344],
#         ...,
#         [0.39974332, 0.26618117, 0.1559196 ],
#         [0.35074505, 0.24317539, 0.15025112],
#         [0.40549883, 0.27608705, 0.14680243]],
#
#        [[0.7611473 , 0.76484007, 0.7479886 ],
#         [0.7749973 , 0.7721541 , 0.7585706 ],
#         [0.7586656 , 0.75451523, 0.7415854 ],
#         ...,
#         [0.3807885 , 0.27467734, 0.1646446 ],
#         [0.39119598, 0.28289396, 0.17090093],
#         [0.40981445, 0.29055512, 0.16875766]]], dtype=float32)>

# %%
pred = model.predict(tf.expand_dims(img, axis=0))
pred
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[1.8548449e-10, 9.9950290e-01, 4.8011058e-04, 5.1487724e-15,
#         1.6271195e-15, 1.5481213e-05, 3.5775213e-19, 1.0358147e-17,
#         1.9361167e-13, 1.6006470e-06]], dtype=float32)

# %%
class_names[np.argmax(pred)]
# Out:
# 'chicken_wings'

# %%
np.argmax(pred)
# Out:
# 1

# %%
class_names
# Out:
# array(['chicken_curry', 'chicken_wings', 'fried_rice', 'grilled_salmon',
#        'hamburger', 'ice_cream', 'pizza', 'ramen', 'steak', 'sushi'],
#       dtype='<U14')

# %%
# !wget https://fooppers.in/wp-content/uploads/2021/01/Salmon-Fish-Fillets-in-Guwahati.jpg
def predict(food_name):
  img = tf.io.read_file(food_name)
  # Decode the read_file into a tensor
  img = tf.image.decode_image(img)
  # Resize the image
  img = tf.image.resize(img, [180, 180])
  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  pred = model.predict(tf.expand_dims(img, axis=0))
  return class_names[np.argmax(pred)]
# Out:
# --2023-02-03 19:27:08--  https://fooppers.in/wp-content/uploads/2021/01/Salmon-Fish-Fillets-in-Guwahati.jpg
# Resolving fooppers.in (fooppers.in)... 217.21.91.38, 2a02:4780:11:887:0:2a78:d43c:2
# Connecting to fooppers.in (fooppers.in)|217.21.91.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105077 (103K) [image/jpeg]
# Saving to: ‘Salmon-Fish-Fillets-in-Guwahati.jpg.2’
#
# Salmon-Fish-Fillets 100%[===================>] 102.61K   245KB/s    in 0.4s
#
# 2023-02-03 19:27:09 (245 KB/s) - ‘Salmon-Fish-Fillets-in-Guwahati.jpg.2’ saved [105077/105077]

# %%
predict("Salmon-Fish-Fillets-in-Guwahati.jpg")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 'chicken_wings'

# %%
# !wget https://static.toiimg.com/photo/51089680.cms
# Out:
# --2023-02-03 19:17:52--  https://static.toiimg.com/photo/51089680.cms
# Resolving static.toiimg.com (static.toiimg.com)... 52.222.139.110, 52.222.139.30, 52.222.139.61, ...
# Connecting to static.toiimg.com (static.toiimg.com)|52.222.139.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘51089680.cms’
#
# 51089680.cms            [ <=>                ]  96.15K  --.-KB/s    in 0.1s
#
# 2023-02-03 19:17:52 (779 KB/s) - ‘51089680.cms’ saved [98459]

# %%
model.evaluate(test_dataset)
# Out:
# 79/79 [==============================] - 9s 106ms/step - loss: 17.0251 - accuracy: 0.7964
# [17.02507781982422, 0.7964000105857849]

# %%
test_model = keras.models.load_model("/content/feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 79/79 [==============================] - 9s 104ms/step - loss: 7.3712 - accuracy: 0.8072
# Test accuracy: 0.807

# %%
test_model.predict(tf.expand_dims(img, axis=0))
# Out:
# 1/1 [==============================] - 0s 232ms/step
# array([[4.5772620e-07, 9.8773128e-01, 1.1354442e-03, 1.5410494e-07,
#         3.7801166e-07, 1.6863098e-03, 2.5344371e-11, 3.8177677e-06,
#         6.1046809e-04, 8.8317152e-03]], dtype=float32)

# %%
predict("/content/10_food_classes_all_data/test/fried_rice/1023430.jpg")
# Out:
# 1/1 [==============================] - 0s 54ms/step
# 'chicken_wings'
